# %% [markdown]
# # Exercise 1 - Sample Mean, Mode and Standard Deviation

# %% [markdown]
# In this program we were asked to calculate the sample mean, the mode and the standard deviation, but with one variant, the user chose what would he want to calculate, and also it is meant to be in an infinite loop, so in this program we asked first to the user what would he want to calculate, with options a, b or c, then it will verify if it was a valid option or not, if it is true then it will change the e value to 0 so it can calculate the sample mean at the end of the while loop, if it's false then it will end the program.
#
# Then we opened a while loop with the condition of i==0 meaning it will stop until i gets a different value other than 0, after starting with the while we placed an input of the data that accepts also text in order to it be possible to stop the programthen we opened an if condition to verify if the number of values is more than 1 and if the inputed string is stop, it is 1 as it starts the counting in 0, that 1 is treated in fact as a 2. It changes the value of e to 1 and the d to "d" so after stopping the loop it won't do anything after it. The other condition is to only verify if m is equal to stop, this is for the purpose of stopping it if we have 2 or more data in order to not take the other condition, which depends of the number of values.
#
# If we decided to introduce a value to the program then it will engage the other option which is the one that accepts all values that are not equal to stop, then it will convert the value to a floating number so we could work with formulas, as we are going to need sumatories, we calculated a sumatory of the data and put all the data in an array called l, and it sums up one number to the n variable as it is treated as the number of values introduced.
#
# After those instructions if the loop is stopped, then it will evaluate the condition of e, if it's 0 then it will calculate the mean, by dividing the sumatory we done in the while loop by the number of values the user introduced.
#
# If the user wrote an "a" at the time he was asked to chose, then the program will show the sample mean and end.
#
# If the user wrote a "b", then it will evaluate each number of the list, and replace the variable that will be shown with the current highest times a number repeats itself, also it verifies if there are multi-modal cases as they will be added in the "modas" array if the highest times a number repeats happens again. Therefore at the end of evaluating, it will determine if the list is a case of one mode, a multi-modal or a non-modal case.
#
# At last, if the user wrote a "c", then the program will calculate how much is each value minus the sample mean, and all that squared, after that it will sum it in order to have the upper part of the process of calculating the variance, after finishing calculating the upper part, then it will be divided by the number of data minus one as the formula indicates, and in order to get the standard deviation we just elevated the variance to the 1/2 to get the square root and the standard deviation, and it will print this result.

# %%
i = 0
n = 0
e = 1
sumd = 0
mode = 0
sums2 = 0
repet = 0

l = []
modas = []

print("\n a) Sample Mean")
print("\n b) Mode")
print("\n c) Standard Deviation")

d = input("\nWhat would you want to calculate? (a/b/c) ")

if d=="a" or d=="b" or d=="c":
    i = 0
    e = 0
else:
    print("\n Please input a valid option!")
    i = 1

while i == 0:
    print("\nType stop to halt the entering of the data\n")
    
    m = input(f"Introduce the data {n+1}: ")
    
    if m == "stop":
        i = 1
        
    if n <= 1 and m == "stop":
        e = 1
        d = "d"
        
    if m != "stop":
        n = n + 1
        h = float(m)
        sumd = sumd + h
        l.append(h)
        
if e == 0:
    mean = sumd/n
        
if d=="a":
    print(f"\nThe sample mean is: {mean}")
    
if d=="b":
    for j in range(0,n):
            for k in range(j,n):
                if l[j]==l[k]:
                    repet = repet + 1
                    if repet > mode:
                        mode = repet
                        oper = l[j]
                        modas *= 0
                        repeat = 0
                    if repet == mode:
                        repeat = repeat + 1
                        modas.append(l[j])
            repet = 0
    
    com = n / mode
    
    if com != repeat:
        if repeat == 1:
            print("The mode is", modas)
        if repeat != 1:
            print("The modes are", modas)
    
    if com == repeat:
        print ("There's no mode")
    
if d=="c":
    for variance in range(0,n):
            sums2 = sums2 + ((l[variance]-mean)**2)
    
    oper = sums2/(n-1)
    
    print(f"\nThe standard deviation is: {oper**0.5}")
# Out:
#  a) Sample Mean
#
#  b) Mode
#
#  c) Standard Deviation
#
# What would you want to calculate? (a/b/c) c
#
# Type stop to halt the entering of the data
#
# Introduce the data 1: 4
#
# Type stop to halt the entering of the data
#
# Introduce the data 2: 2
#
# Type stop to halt the entering of the data
#
# Introduce the data 3: 4
#
# Type stop to halt the entering of the data
#
# Introduce the data 4: 6
#
# Type stop to halt the entering of the data
#
# Introduce the data 5: 7
#
# Type stop to halt the entering of the data
#
# Introduce the data 6: stop
#
# The standard deviation is: 1.9493588689617927
